# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.naive_bayes import MultinomialNB
from scipy.stats import bayes_mvs

df = pd.read_excel('Immunotherapy.xlsx')



##Colunas do DataFrame
x = df[['sex','age','Time','Number_of_Warts', 'Type','Area','induration_diameter']]
y = df[['Result_of_Treatment']]

#Separação de testes
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.25, random_state=0)

modelo = MultinomialNB()
#modelo.fit(x_treino, y_treino)
#modelo.score(x_teste, y_teste)


df.loc[df['Result_of_Treatment'] == 1, 'Result_of_Treatment'] = "Sucesso"
df.loc[df['Result_of_Treatment'] == 0, 'Result_of_Treatment'] = "Fracasso"
df.loc[df['sex'] == 1, 'sex'] = "Feminino"
df.loc[df['sex'] == 2, 'sex'] = "Masculino"

df
# Out:
#           sex  age   Time  Number_of_Warts  Type  Area  induration_diameter  \
# 0    Feminino   22   2.25               14     3    51                   50
# 1    Feminino   15   3.00                2     3   900                   70
# 2    Feminino   16  10.50                2     1   100                   25
# 3    Feminino   27   4.50                9     3    80                   30
# 4    Feminino   20   8.00                6     1    45                    8
# 5    Feminino   15   5.00                3     3    84                    7
# 6    Feminino   35   9.75                2     2     8                    6
# 7   Masculino   28   7.50                4     1     9                    2
# 8   Masculino   19   6.00                2     1   225                    8
# 9   Masculino   32  12.00                6     3    35                    5
# 10  Masculino   33   6.25                2     1    30                    3
# 11  Masculino   17   5.75               12     3    25                    7
# 12  Masculino   15   1.75                1     2    49                    7
# 13  Masculino   15   5.50               12     1    48                    7
# 14  Masculino   16  10.00                7     1   143                    6
# 15  Masculino   33   9.25                2     2   150                    8
# 16  Masculino   26   7.75                6     2     6                    5
# 17  Masculino   23   7.50               10     2    43                    3
# 18  Masculino   15   6.50               19     1    56                    7
# 19  Masculino   26   6.75                2     1     6                    6
# 20   Feminino   22   1.25                3     3    47                    3
# 21  Masculino   19   2.25                2     1    60                    7
# 22  Masculino   26  10.50                6     1    50                    9
# 23   Feminino   25   5.75                2     1   300                    7
# 24  Masculino   17  11.25                4     3    70                    7
# 25   Feminino   27   5.00                2     1    20                    5
# 26  Masculino   24   4.75               10     3    30                   45
# 27   Feminino   15  11.00                6     1    30                   25
# 28  Masculino   34  11.50               12     1    25                   50
# 29  Masculino   20   7.75               18     3    45                    2
# ..        ...  ...    ...              ...   ...   ...                  ...
# 60  Masculino   47   3.75               14     2    67                   50
# 61  Masculino   19   2.25                8     2    42                   70
# 62  Masculino   33   8.00                5     1    63                   25
# 63  Masculino   15   4.00               12     1    72                   30
# 64   Feminino   17   8.50                2     1    44                    8
# 65   Feminino   29   5.00               12     3    75                    7
# 66   Feminino   27  11.75                8     1   208                    6
# 67  Masculino   51   6.00                6     1    80                    2
# 68   Feminino   35   6.75                4     3    41                    8
# 69  Masculino   47  10.75                8     1    57                    5
# 70   Feminino   43   8.00                1     1    59                    3
# 71   Feminino   15   4.00                4     3    25                    7
# 72   Feminino   33   1.75                7     2   379                    7
# 73  Masculino   51   4.00                1     1    65                    7
# 74   Feminino   45   6.50                9     2    49                    6
# 75  Masculino   47   9.25               13     2   367                    8
# 76   Feminino   18  11.75                5     2    13                    5
# 77  Masculino   46   7.75                8     1    40                    3
# 78   Feminino   43  11.00                7     1   507                    7
# 79  Masculino   28  11.00                3     3    91                    6
# 80   Feminino   30   1.00                2     1    88                    3
# 81  Masculino   16   2.00               11     1    47                    7
# 82  Masculino   42   8.75                8     2    73                    9
# 83  Masculino   15   8.00                1     1    55                    7
# 84  Masculino   53   7.25                6     1    81                    7
# 85   Feminino   40   5.50                8     3    69                    5
# 86   Feminino   38   7.50                8     2    56                   45
# 87   Feminino   46  11.50                4     1    91                   25
# 88   Feminino   32  12.00                9     1    43                   50
# 89  Masculino   23   6.75                6     1    19                    2
#
#    Result_of_Treatment
# 0              Sucesso
# 1              Sucesso
# 2              Sucesso
# 3              Sucesso
# 4              Sucesso
# 5              Sucesso
# 6              Sucesso
# 7              Sucesso
# 8              Sucesso
# 9             Fracasso
# 10             Sucesso
# 11             Sucesso
# 12            Fracasso
# 13             Sucesso
# 14             Sucesso
# 15             Sucesso
# 16             Sucesso
# 17             Sucesso
# 18             Sucesso
# 19             Sucesso
# 20             Sucesso
# 21             Sucesso
# 22            Fracasso
# 23             Sucesso
# 24             Sucesso
# 25             Sucesso
# 26             Sucesso
# 27            Fracasso
# 28            Fracasso
# 29             Sucesso
# ..                 ...
# 60             Sucesso
# 61             Sucesso
# 62             Sucesso
# 63             Sucesso
# 64             Sucesso
# 65             Sucesso
# 66            Fracasso
# 67             Sucesso
# 68             Sucesso
# 69            Fracasso
# 70             Sucesso
# 71             Sucesso
# 72            Fracasso
# 73             Sucesso
# 74             Sucesso
# 75             Sucesso
# 76             Sucesso
# 77             Sucesso
# 78             Sucesso
# 79            Fracasso
# 80             Sucesso
# 81             Sucesso
# 82            Fracasso
# 83             Sucesso
# 84             Sucesso
# 85             Sucesso
# 86             Sucesso
# 87            Fracasso
# 88            Fracasso
# 89             Sucesso
#
# [90 rows x 8 columns]
